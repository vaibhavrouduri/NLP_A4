# %%
# !unzip hw4.zip -d .

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (3.1.0)
# Requirement already satisfied: setuptools in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.8.93)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)

# %%
# !pip install datasets==2.18.0 evaluate==0.4.2
# Out:
# Requirement already satisfied: datasets==2.18.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (2.18.0)
# Requirement already satisfied: evaluate==0.4.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: filelock in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (22.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (0.3.8)
# Requirement already satisfied: pandas in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (4.67.1)
# Requirement already satisfied: xxhash in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (3.6.0)
# Requirement already satisfied: multiprocess in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets==2.18.0) (2024.2.0)
# Requirement already satisfied: aiohttp in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (3.13.2)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (0.36.0)
# Requirement already satisfied: packaging in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from datasets==2.18.0) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiohttp->datasets==2.18.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiohttp->datasets==2.18.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiohttp->datasets==2.18.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiohttp->datasets==2.18.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiohttp->datasets==2.18.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiohttp->datasets==2.18.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiohttp->datasets==2.18.0) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets==2.18.0) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp->datasets==2.18.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub>=0.19.4->datasets==2.18.0) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests>=2.19.0->datasets==2.18.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests>=2.19.0->datasets==2.18.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests>=2.19.0->datasets==2.18.0) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->datasets==2.18.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->datasets==2.18.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->datasets==2.18.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.18.0) (1.17.0)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# !pip install --upgrade pip
# !pip install transformers==4.40.2
# Out:
# Requirement already satisfied: pip in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (25.3)
# Requirement already satisfied: transformers==4.40.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (4.40.2)
# Requirement already satisfied: filelock in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (2025.11.3)
# Requirement already satisfied: requests in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (2.32.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from transformers==4.40.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.2) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.2) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.2) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->transformers==4.40.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->transformers==4.40.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->transformers==4.40.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests->transformers==4.40.2) (2025.11.12)

# %%
import transformers

# %%
# %cd hw4/hw4-code/part-1-code
# Out:
# /teamspace/studios/this_studio/hw4/hw4-code/part-1-code
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python3 main.py --train --eval --debug_train
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map: 100%|███████████████████████| 25000/25000 [00:05<00:00, 4259.06 examples/s]
# Debug training...
# len(train_dataloader): 500
# len(eval_dataloader): 125
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|███████████████████████████████████████| 1500/1500 [04:35<00:00,  5.45it/s]Training completed...
# Saving Model....
# 100%|███████████████████████████████████████| 1500/1500 [04:36<00:00,  5.42it/s]
# Downloading builder script: 4.20kB [00:00, 19.1MB/s]
# 100%|█████████████████████████████████████████| 125/125 [00:07<00:00, 16.29it/s]
# Score:  {'accuracy': 0.891}

# %%
# !python3 main.py --train --eval
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map: 100%|███████████████████████| 50000/50000 [00:11<00:00, 4285.86 examples/s]
# Actual training...
# len(train_dataloader): 3125
# len(eval_dataloader): 3125
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|███████████████████████████████████████| 9375/9375 [28:41<00:00,  5.45it/s]Training completed...
# Saving Model....
# 100%|███████████████████████████████████████| 9375/9375 [28:42<00:00,  5.44it/s]
# 100%|███████████████████████████████████████| 3125/3125 [03:06<00:00, 16.72it/s]
# Score:  {'accuracy': 0.92368}

# %%
# !python3 main.py --eval_transformed --debug_transformation
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Actual training...
# len(train_dataloader): 3125
# len(eval_dataloader): 3125
# Map: 100%|█████████████████████████████████| 5/5 [00:02<00:00,  1.75 examples/s]
# Original Example  0
# {'text': "<br /><br />When I unsuspectedly rented A Thousand Acres, I thought I was in for an entertaining King Lear story and of course Michelle Pfeiffer was in it, so what could go wrong?<br /><br />Very quickly, however, I realized that this story was about A Thousand Other Things besides just Acres. I started crying and couldn't stop until long after the movie ended. Thank you Jane, Laura and Jocelyn, for bringing us such a wonderfully subtle and compassionate movie! Thank you cast, for being involved and portraying the characters with such depth and gentleness!<br /><br />I recognized the Angry sister; the Runaway sister and the sister in Denial. I recognized the Abusive Husband and why he was there and then the Father, oh oh the Father... all superbly played. I also recognized myself and this movie was an eye-opener, a relief, a chance to face my OWN truth and finally doing something about it. I truly hope A Thousand Acres has had the same effect on some others out there.<br /><br />Since I didn't understand why the cover said the film was about sisters fighting over land -they weren't fighting each other at all- I watched it a second time. Then I was able to see that if one hadn't lived a similar story, one would easily miss the overwhelming undercurrent of dread and fear and the deep bond between the sisters that runs through it all. That is exactly the reason why people in general often overlook the truth about their neighbors for instance.<br /><br />But yet another reason why this movie is so perfect!<br /><br />I don't give a rat's ass (pardon my French) about to what extend the King Lear story is followed. All I know is that I can honestly say: this movie has changed my life.<br /><br />Keep up the good work guys, you CAN and DO make a difference.<br /><br />", 'label': 1}
#
#
# Transformed Example  0
# {'text': "< bromine / > < br / > when i unsuspectedly rented thousand acres , idea i in entertaining king lear story and of course michelle pfeiffer Washington it , so could turn wrongfulness ? < bromine / > < br / > very quickly , however , i realized that this story about a thousand other things besides just acres . start crying could n't halt long after the movie ended . thank you jane , laura jocelyn , for bringing us a wonderfully subtle and compassionate flick ! thank cast , for involve and depicting the characters depth and gentleness ! < bromine / > < br / > recognized angry sister ; the runaway sister the sister denial . iodin recognized the scurrilous husband was there then the father , oh oh the begetter ... all terrifically played . i also recognized myself and this flick an eye-opener , relief , angstrom chance face truth and eventually make something astir . truly hope angstrom thousand acres has had the same effect on some others there. < br / > < br / > since i did n't understand the cover said the film was about sis fighting over land -they were n't scrap other at all- i watched it sec clip . then Washington able to see if one n't lived similar tale , one would easily fille the overwhelming undercurrent dread and fear deep bond between sis that runs through it all . is exactly the reason why people general often overlook truth about neighbors instance. < br / > < br / > but yet another reason movie so perfect ! < bromine / > < bromine / > iodin bash n't give rat 's ass ( pardon french ) extend the king lear story followed . i know i tin honestly say : movie changed my life. < bromine / > < br / > keep up the good work guys , can and do brand a difference. < br / > < bromine / >", 'label': 1}
# ==============================
# Original Example  1
# {'text': "This is the latest entry in the long series of films with the French agent, O.S.S. 117 (the French answer to James Bond). The series was launched in the early 1950's, and spawned at least eight films (none of which was ever released in the U.S.). 'O.S.S.117:Cairo,Nest Of Spies' is a breezy little comedy that should not...repeat NOT, be taken too seriously. Our protagonist finds himself in the middle of a spy chase in Egypt (with Morroco doing stand in for Egypt) to find out about a long lost friend. What follows is the standard James Bond/Inspector Cloussou kind of antics. Although our man is something of an overt xenophobe,sexist,homophobe, it's treated as pure farce (as I said, don't take it too seriously). Although there is a bit of rough language & cartoon violence, it's basically okay for older kids (ages 12 & up). As previously stated in the subject line, just sit back,pass the popcorn & just enjoy.", 'label': 1}
#
#
# Transformed Example  1
# {'text': "the latest entry in long series of films French agent , o.s.s . 117 ( french answer to james bond ) . series was launched early 1950 's , and spawn at least eight picture ( none of ever released the u.s. ) . ' o.s.s.117 : cairo , nest of spies ' is angstrom breezy little comedy that should not ... repetition not , take earnestly . our booster finds middle a spy chase Egypt ( morroco doing pedestal for egypt ) to find out about a long lost friend . what follows is the measure james bond/inspector cloussou kind of antics . although our man is something of overt xenophobe , sexist , homophobe , it 's treat as pure travesty ( as said , do n't take it seriously ) . although there is angstrom bit of rough language & cartoon force , 's basically okay older shaver ( ages 12 & up ) . antecedently stated the subject line , just sit back , pass the popcorn & just enjoy .", 'label': 1}
# ==============================
# Original Example  2
# {'text': 'This movie was so frustrating. Everything seemed energetic and I was totally prepared to have a good time. I at least thought I\'d be able to stand it. But, I was wrong. First, the weird looping? It was like watching "America\'s Funniest Home Videos". The damn parents. I hated them so much. The stereo-typical Latino family? I need to speak with the person responsible for this. We need to have a talk. That little girl who was always hanging on someone? I just hated her and had to mention it. Now, the final scene transcends, I must say. It\'s so gloriously bad and full of badness that it is a movie of its own. What crappy dancing. Horrible and beautiful at once.', 'label': 0}
#
#
# Transformed Example  2
# {'text': "movie frustrating . everything seemed energetic and totally prepare to good time . i least thought 'd be able to stand it . but , was wrong . first , the weird looping ? like watching `` america 's amusing home picture '' . damn parents . hated them much . stereo-typical latino family ? demand speak with somebody responsible for this . demand to a talk . little girl always hanging someone ? just detest her reference it . now , the final scene transcends , must say . it 's gloriously bad full badness that it picture its own . what crappy dancing . atrocious beautiful once .", 'label': 0}
# ==============================
# Original Example  3
# {'text': 'I was truly and wonderfully surprised at "O\' Brother, Where Art Thou?" The video store was out of all the movies I was planning on renting, so then I came across this. I came home and as I watched I became engrossed and found myself laughing out loud. The Coen\'s have made a magnificiant film again. But I think the first time you watch this movie, you get to know the characters. The second time, now that you know them, you laugh sooo hard it could hurt you. I strongly would reccomend ANYONE seeing this because if you are not, you are truly missing a film gem for the ages. 10/10', 'label': 1}
#
#
# Transformed Example  3
# {'text': "was truly wonderfully surprise `` o ' brother , where art thou ? '' video store was the pic i Washington planning on renting , then came across this . i came home i watch became engross and found laugh out loud . coen 's have made magnificiant film . think the first time watch this movie , get know the characters . sec time , now know them , laugh sooo hard it could harm . i strongly would reccomend anyone seeing this because if not , you are truly missing a film gem for the ages . 10/10", 'label': 1}
# ==============================
# Original Example  4
# {'text': 'This movie spends most of its time preaching that it is the script that makes the movie, but apparently there was no script when they shot this waste of time! The trailer makes this out to be a comedy, but the film can\'t decide if it wants to be a comedy, a drama, a romance or an action film. Press releases indicated that Shatner and Hamlin made this movie because they loved the script (what were they thinking?). If you like William Shatner (I do) see "Free Enterprise" instead.', 'label': 0}
#
#
# Transformed Example  4
# {'text': "movie spends time discourse that is the script that makes movie , but apparently no script they shot this waste time ! trailer makes comedy , simply film ca n't decide it wants to a comedy , drama , romance or action film . insistence release indicated that shatner hamlin made movie because loved the script ( what thinking ? ) . like william shatner ( i bash ) see `` free endeavor '' instead .", 'label': 0}
# ==============================

# %%
# !python3 main.py --eval_transformed
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Actual training...
# len(train_dataloader): 3125
# len(eval_dataloader): 3125
# Map: 100%|████████████████████████| 25000/25000 [01:52<00:00, 221.44 examples/s]
# Map: 100%|███████████████████████| 25000/25000 [00:05<00:00, 4487.01 examples/s]
# Downloading builder script: 4.20kB [00:00, 16.9MB/s]
# 100%|███████████████████████████████████████| 3125/3125 [03:08<00:00, 16.58it/s]
# Score:  {'accuracy': 0.87008}

# %%
# !python3 main.py --train_augmented --eval_transformed
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Actual training...
# len(train_dataloader): 3125
# len(eval_dataloader): 3125
# Map: 100%|██████████████████████████| 5000/5000 [00:27<00:00, 182.86 examples/s]
# Map: 100%|███████████████████████| 30000/30000 [00:06<00:00, 4384.74 examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|█████████████████████████████████████| 11250/11250 [34:25<00:00,  5.45it/s]Training completed...
# Saving Model....
# 100%|█████████████████████████████████████| 11250/11250 [34:26<00:00,  5.45it/s]
# Map: 100%|████████████████████████| 25000/25000 [01:47<00:00, 233.46 examples/s]
# Map: 100%|███████████████████████| 25000/25000 [00:05<00:00, 4437.07 examples/s]
# 100%|███████████████████████████████████████| 3125/3125 [03:06<00:00, 16.73it/s]
# Score:  {'accuracy': 0.9166}

# %%
# !python3 main.py --eval --model_dir out_augmented
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Actual training...
# len(train_dataloader): 3125
# len(eval_dataloader): 3125
# 100%|███████████████████████████████████████| 3125/3125 [03:07<00:00, 16.66it/s]
# Score:  {'accuracy': 0.93192}

# %%
# !python3 main.py --eval_transformed --model_dir out_augmented
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Actual training...
# len(train_dataloader): 3125
# len(eval_dataloader): 3125
# Map: 100%|████████████████████████| 25000/25000 [01:53<00:00, 220.90 examples/s]
# Map: 100%|███████████████████████| 25000/25000 [00:05<00:00, 4498.65 examples/s]
# 100%|███████████████████████████████████████| 3125/3125 [03:08<00:00, 16.62it/s]
# Score:  {'accuracy': 0.91736}
